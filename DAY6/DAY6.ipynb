# %% [markdown]
# ### Pandas
#
# - DataFrame
#     - it is a table with multiple rows and columns
#     - it can read different types of files
#     - example : csv,excel,html,json

# %%
import pandas as pd

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# creating a dataframe

d1 = pd.DataFrame([1,2,3,4])
d1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
d2 = pd.DataFrame([["apssdc",22,2021],["workshop",5,2021]])
d2
# Out:
#           0   1     2
# 0    apssdc  22  2021
# 1  workshop   5  2021

# %%
d2 = pd.DataFrame([["apssdc",22,2021],["workshop",5,2021]],columns = ("name","date","year"),
                  index = ["a","b"])

# %%
d2
# Out:
#        name  date  year
# a    apssdc    22  2021
# b  workshop     5  2021

# %%
dict1 = {"Name":["apssdc","workshop"],"date":[22,5],"year":[2021,2020]}
dict1
# Out:
# {'Name': ['apssdc', 'workshop'], 'date': [22, 5], 'year': [2021, 2020]}

# %%
d3 = pd.DataFrame(dict1,index = ["a","b"])
d3
# Out:
#        Name  date  year
# a    apssdc    22  2021
# b  workshop     5  2020

# %%
d3.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
d3.columns
# Out:
# Index(['Name', 'date', 'year'], dtype='object')

# %%
d3.shape
# Out:
# (2, 3)

# %%
# Accessing the elements

# %%
d3["Name"]# getting columns
# Out:
# a      apssdc
# b    workshop
# Name: Name, dtype: object

# %%
d3["Name"]["b"]
# Out:
# 'workshop'

# %%
d3["Name"][1]
# Out:
# 'workshop'

# %%
d3[-1:]
# Out:
#        Name  date  year
# b  workshop     5  2020

# %%
d3[0:1]
# Out:
#      Name  date  year
# a  apssdc    22  2021

# %%
# Load dataset

# %%
data = pd.read_csv("market.csv")

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
data.shape
# Out:
# (8399, 10)

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.tail(2)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
data.sample(3)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 1102  Ord_4663  Prod_9  SHP_6498  Cust_1612  2026.42      0.03
# 337   Ord_4062  Prod_5  SHP_5665  Cust_1385  2504.41      0.01
# 1293     Ord_5  Prod_3     SHP_6     Cust_5    93.54      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 1102              50  655.36           9.83                 0.40
# 337               30 -547.89          48.20                 0.74
# 1293              12  -54.04           7.72                 0.38

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
# statisical Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
# selecting rows

# %%
data[10:20]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.010      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708    465.900      0.05
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088    305.050      0.04
# 13  Ord_2207  Prod_11  SHP_3093   Cust_839   3364.248      0.10
# 14  Ord_2207  Prod_10  SHP_3006   Cust_839   1410.930      0.08
# 15  Ord_2280   Prod_5  SHP_3114   Cust_839    460.690      0.06
# 16  Ord_2282   Prod_9  SHP_3122   Cust_839    443.460      0.06
# 17  Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.930      0.02
# 18  Ord_4427   Prod_6  SHP_6171  Cust_1521    283.130      0.08
# 19   Ord_996  Prod_13  SHP_1378   Cust_371     41.970      0.05
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 10              43  1675.98           0.99                 0.56
# 11              38    79.34           4.86                 0.38
# 12              27    23.12           3.37                 0.57
# ...

# %%
data[10:20:2]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.01      0.01              43
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 14  Ord_2207  Prod_10  SHP_3006   Cust_839  1410.93      0.08              10
# 16  Ord_2282   Prod_9  SHP_3122   Cust_839   443.46      0.06              30
# 18  Ord_4427   Prod_6  SHP_6171  Cust_1521   283.13      0.08              45
#
#      Profit  Shipping_Cost  Product_Base_Margin
# 10  1675.98           0.99                 0.56
# 12    23.12           3.37                 0.57
# 14  -317.48          36.09                 0.77
# 16   193.12           1.39                 0.38
# 18  -141.26           6.81                 0.36

# %%
# selecting columns

# %%
data["Sales"].head()
# Out:
# 0     136.81
# 1      42.27
# 2    4701.69
# 3    2337.89
# 4    4233.15
# Name: Sales, dtype: float64

# %%
data[["Sales","Profit","Discount"]].head()
# Out:
#    Sales  Profit  Discount
# 0  False   False     False
# 1  False   False     False
# 2  False   False     False
# 3  False   False     False
# 4  False   False     False

# %%
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
# iloc and loc
# iloc-->Position based index
#loc -->Label based index

# %%
data.iloc[1000]
# Out:
# Ord_id                 Ord_1895
# Prod_id                  Prod_4
# Ship_id                SHP_2601
# Cust_id                Cust_686
# Sales                   2433.55
# Discount                   0.05
# Order_Quantity               23
# Profit                   355.93
# Shipping_Cost              8.08
# Product_Base_Margin        0.57
# Name: 1000, dtype: object

# %%
data.iloc[1000:2000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 1000  Ord_1895   Prod_4  SHP_2601   Cust_686  2433.5500      0.05
# 1001  Ord_1910   Prod_8  SHP_3095   Cust_891   587.2000      0.08
# 1002  Ord_1910  Prod_12  SHP_3096   Cust_891   110.7900      0.05
# 1003  Ord_2025   Prod_6  SHP_2769   Cust_897   162.3900      0.10
# 1004    Ord_97   Prod_5   SHP_132    Cust_70   426.3400      0.00
# 1005   Ord_187  Prod_12   SHP_252    Cust_70    35.1700      0.03
# 1006   Ord_319   Prod_1   SHP_426    Cust_70   178.4500      0.09
# 1007   Ord_319   Prod_5   SHP_425    Cust_70   413.8600      0.00
# 1008    Ord_28   Prod_3    SHP_38    Cust_23    42.6600      0.06
# 1009  Ord_1173   Prod_6  SHP_1619   Cust_449   355.9700      0.03
# 1010  Ord_1182  Prod_13  SHP_1631   Cust_449    79.1400      0.09
# 1011  Ord_1172   Prod_6  SHP_1617   Cust_449   240.1800      0.06
# 1012  Ord_1173   Prod_3  SHP_1619   Cust_449   887.4500      0.10
# ...

# %%
data.iloc[[2,5,7,1000]]
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2     Ord_5446  Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 5     Ord_5446  Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 7     Ord_4725  Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 1000  Ord_1895  Prod_4  SHP_2601   Cust_686  2433.5500      0.05
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# 5                 23   -47.64           6.15                 0.37
# 7                 48  1137.91           0.99                 0.55
# 1000              23   355.93           8.08                 0.57

# %%
data.iloc[3:10,4:]
# Out:
#        Sales  Discount  Order_Quantity   Profit  Shipping_Cost  \
# 3  2337.8900      0.09              43   729.34          14.30
# 4  4233.1500      0.08              35  1219.87          26.30
# 5   164.0200      0.03              23   -47.64           6.15
# 6    14.7600      0.01               5     1.32           0.50
# 7  3410.1575      0.10              48  1137.91           0.99
# 8   162.0000      0.01              33    45.84           0.71
# 9    57.2200      0.07               8   -27.72           6.60
#
#    Product_Base_Margin
# 3                 0.37
# 4                 0.38
# 5                 0.37
# 6                 0.36
# 7                 0.55
# 8                 0.52
# 9                 0.37

# %%
data.loc[4,"Sales"]
# Out:
# 4233.15

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.loc[8,"Sales"]
# Out:
# 162.0

# %%
# Filtering

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
data[data["Sales"]>20000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.510      0.00
# 197   Ord_2753   Prod_3  SHP_3778   Cust_997  23106.460      0.08
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.400      0.05
# 734   Ord_4705  Prod_17  SHP_6566  Cust_1592  21320.580      0.09
# 798   Ord_2477  Prod_11  SHP_3394   Cust_939  20596.580      0.09
# 1184  Ord_5181  Prod_17  SHP_7238  Cust_1750  23775.560      0.03
# 1265  Ord_5250  Prod_17  SHP_7331  Cust_1769  24105.870      0.07
# 1363    Ord_82  Prod_14   SHP_108    Cust_62  21506.770      0.06
# 1448  Ord_2673   Prod_1  SHP_3661  Cust_1027  21337.270      0.02
# 1740  Ord_3667  Prod_17  SHP_5082  Cust_1291  21532.260      0.09
# 1771  Ord_5347  Prod_17  SHP_7468  Cust_1797  21134.710      0.06
# 1787  Ord_2872  Prod_14  SHP_7219  Cust_1748  21555.600      0.02
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.210      0.09
# ...

# %%
data[(data["Sales"]>20000) & (data["Profit"]>10000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3241   Ord_118   Prod_3   SHP_161    Cust_63  23792.93      0.00
# 4124  Ord_2345   Prod_3  SHP_3218   Cust_937  25409.63      0.02
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 5042  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 5971  Ord_3059  Prod_17  SHP_4249  Cust_1143  21921.28      0.04
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6660  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# 6765  Ord_5186  Prod_17  SHP_7247  Cust_1763  26095.13      0.03
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 385               49  14440.39          24.49                 0.37
# ...

# %%
# sorting
# Ascending order
# Descending order

# %%
data.sort_values(by = ["Prod_id"],inplace=True)

# %%
data
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1593  Ord_1067  Prod_1  SHP_1474   Cust_397   7333.45      0.07
# 5429  Ord_2414  Prod_1  SHP_3312   Cust_940    825.82      0.00
# 3986   Ord_168  Prod_1   SHP_227    Cust_61  18235.47      0.03
# 8102  Ord_3954  Prod_1  SHP_5495  Cust_1369   1556.61      0.06
# 4794  Ord_4923  Prod_1  SHP_6867  Cust_1681   1438.33      0.08
# 2595  Ord_4464  Prod_1  SHP_6219  Cust_1445    279.77      0.07
# 7772  Ord_3210  Prod_1  SHP_4452  Cust_1183    494.34      0.05
# 5570   Ord_909  Prod_1  SHP_1253   Cust_307    189.04      0.08
# 2596  Ord_4249  Prod_1  SHP_5933  Cust_1445    299.01      0.09
# 2131  Ord_4792  Prod_1  SHP_6679  Cust_1568    292.38      0.05
# 2597  Ord_4250  Prod_1  SHP_5936  Cust_1445   6152.80      0.04
# 1014  Ord_1172  Prod_1  SHP_1618   Cust_449    529.28      0.10
# 2992  Ord_1382  Prod_1  SHP_1906   Cust_532   2367.99      0.04
# 3996   Ord_479  Prod_1   SHP_645   Cust_175   1132.54      0.00
# ...

# %%
data.sort_values(by = ["Prod_id"],inplace=True,ascending=False)

# %%
data.head(10)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1593  Ord_1067  Prod_1  SHP_1474   Cust_397   7333.45      0.07
# 5429  Ord_2414  Prod_1  SHP_3312   Cust_940    825.82      0.00
# 3986   Ord_168  Prod_1   SHP_227    Cust_61  18235.47      0.03
# 8102  Ord_3954  Prod_1  SHP_5495  Cust_1369   1556.61      0.06
# 4794  Ord_4923  Prod_1  SHP_6867  Cust_1681   1438.33      0.08
# 2595  Ord_4464  Prod_1  SHP_6219  Cust_1445    279.77      0.07
# 7772  Ord_3210  Prod_1  SHP_4452  Cust_1183    494.34      0.05
# 5570   Ord_909  Prod_1  SHP_1253   Cust_307    189.04      0.08
# 2596  Ord_4249  Prod_1  SHP_5933  Cust_1445    299.01      0.09
# 2131  Ord_4792  Prod_1  SHP_6679  Cust_1568    292.38      0.05
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 1593              27  -207.28          35.00                 0.80
# 5429              36 -1049.26          35.00                 0.84
# ...

# %% [markdown]
# #### Data Preprocessing with scikit -Learn
#
# - problems :
#     - insufficient of data
#     - too much of data
#     - outliers
#     - Missing data
#     - Duplicate data
#
# - Scaling Techniques
#     - Standard Scalar
#     - Robust Scalar
#     - Normalization
#     - Range Scalar(Min Max Scalar)

# %% [markdown]
# - Standard Scalar
# - [xi-mean(x)]/std(x)

# %%
from sklearn import preprocessing

# %%
sc1 = preprocessing.StandardScaler()

# %%
print(dir(preprocessing))
# Out:
# ['Binarizer', 'CategoricalEncoder', 'FunctionTransformer', 'Imputer', 'KBinsDiscretizer', 'KernelCenterer', 'LabelBinarizer', 'LabelEncoder', 'MaxAbsScaler', 'MinMaxScaler', 'MultiLabelBinarizer', 'Normalizer', 'OneHotEncoder', 'OrdinalEncoder', 'PolynomialFeatures', 'PowerTransformer', 'QuantileTransformer', 'RobustScaler', 'StandardScaler', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_discretization', '_encoders', '_function_transformer', 'add_dummy_feature', 'base', 'binarize', 'data', 'imputation', 'label', 'label_binarize', 'maxabs_scale', 'minmax_scale', 'normalize', 'power_transform', 'quantile_transform', 'robust_scale', 'scale']

# %%
data.head()
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1593  Ord_1067  Prod_1  SHP_1474   Cust_397   7333.45      0.07
# 5429  Ord_2414  Prod_1  SHP_3312   Cust_940    825.82      0.00
# 3986   Ord_168  Prod_1   SHP_227    Cust_61  18235.47      0.03
# 8102  Ord_3954  Prod_1  SHP_5495  Cust_1369   1556.61      0.06
# 4794  Ord_4923  Prod_1  SHP_6867  Cust_1681   1438.33      0.08
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 1593              27  -207.28          35.00                 0.80
# 5429              36 -1049.26          35.00                 0.84
# 3986              48  1166.93          99.00                 0.65
# 8102              17  -485.55          35.00                 0.83
# 4794              43   163.38           8.22                 0.57

# %%
data1 = data[["Sales","Discount","Order_Quantity","Profit","Shipping_Cost"]]

# %%
data1.head()
# Out:
#          Sales  Discount  Order_Quantity   Profit  Shipping_Cost
# 1593   7333.45      0.07              27  -207.28          35.00
# 5429    825.82      0.00              36 -1049.26          35.00
# 3986  18235.47      0.03              48  1166.93          99.00
# 8102   1556.61      0.06              17  -485.55          35.00
# 4794   1438.33      0.08              43   163.38           8.22

# %%
sc1_d = sc1.fit_transform(data1)
sc1_d
# Out:
# C:\Users\Alekhya\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Alekhya\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[ 1.55029968,  0.63884009,  0.09863568, -0.32464502,  1.28375207],
#        [-0.2650213 , -1.56095642,  0.72017367, -1.02829918,  1.28375207],
#        [ 4.59144764, -0.61818648,  1.54889099,  0.82380102,  4.99109786],
#        ...,
#        [-0.47859586, -1.24669977, -1.28255985, -0.1460363 , -0.59888446],
#        [-0.36331307, -0.61818648, -0.86820119, -0.04435502, -0.35790699],
#        [-0.39835511, -1.56095642,  0.78923345, -0.23436287, -0.26348552]])

# %%
data1.columns
# Out:
# Index(['Sales', 'Discount', 'Order_Quantity', 'Profit', 'Shipping_Cost'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 1593 to 8177
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.0+ MB

# %%
sc1_data = pd.DataFrame(sc1_d,columns=data1.columns)
sc1_data.head()
# Out:
#       Sales  Discount  Order_Quantity    Profit  Shipping_Cost
# 0  1.550300  0.638840        0.098636 -0.324645       1.283752
# 1 -0.265021 -1.560956        0.720174 -1.028299       1.283752
# 2  4.591448 -0.618186        1.548891  0.823801       4.991098
# 3 -0.061165  0.324583       -0.591962 -0.557199       1.283752
# 4 -0.094160  0.953097        1.203592 -0.014879      -0.267540

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(5,5))
ax1.set_title("original data")
sns.kdeplot(data1["Sales"],ax=ax1)
sns.kdeplot(data1["Discount"],ax=ax1)
sns.kdeplot(data1["Order_Quantity"],ax=ax1)
sns.kdeplot(data1["Profit"],ax=ax1)
sns.kdeplot(data1["Shipping_Cost"],ax=ax1)
ax2.set_title("standarad scalar")
sns.kdeplot(sc1_data["Sales"],ax=ax2)
sns.kdeplot(sc1_data["Discount"],ax=ax2)
sns.kdeplot(sc1_data["Order_Quantity"],ax=ax2)
sns.kdeplot(sc1_data["Profit"],ax=ax2)
sns.kdeplot(sc1_data["Shipping_Cost"],ax=ax2)
plt.show()

# %%
# robust scalar

# %%
rs = preprocessing.RobustScaler()

# %%
rs_d = rs.fit_transform(data1)
rs_d
# Out:
# array([[ 4.39558145,  0.33333333,  0.04      , -0.8362831 ,  2.70626754],
#        [ 0.24033841, -0.83333333,  0.4       , -4.25806189,  2.70626754],
#        [11.3567244 , -0.33333333,  0.88      ,  4.74846077,  8.69317119],
#        ...,
#        [-0.24853061, -0.66666667, -0.76      ,  0.0322679 , -0.33395697],
#        [ 0.01534999, -0.33333333, -0.52      ,  0.52673074,  0.05519177],
#        [-0.06486072, -0.83333333,  0.44      , -0.39725276,  0.20767072]])

# %%
da = pd.DataFrame(rs_d,columns=data1.columns)
da.head()
# Out:
#        Sales  Discount  Order_Quantity    Profit  Shipping_Cost
# 0   4.395581  0.333333            0.04 -0.836283       2.706268
# 1   0.240338 -0.833333            0.40 -4.258062       2.706268
# 2  11.356724 -0.333333            0.88  4.748461       8.693171
# 3   0.706961  0.166667           -0.36 -1.967163       2.706268
# 4   0.631437  0.500000            0.68  0.670067       0.201123
